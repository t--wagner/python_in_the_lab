# %% [markdown]
# <center> <h1>Python in the Lab</h1> </center>

# %% [markdown]
# # Topics
#
# 1. [Python](https://docs.python.org/3/tutorial/index.html)
#     1. [Control Flow](https://docs.python.org/3/tutorial/controlflow.html)
#     * [Data Structures](https://docs.python.org/3/tutorial/datastructures.html)
#     * [Modules and Packages](https://docs.python.org/3/tutorial/modules.html)
#     * [Object-oriented programming](https://docs.python.org/3/tutorial/classes.html)
#     * [Iterators](https://docs.python.org/3/tutorial/classes.html#iterators)
#     * [Generators](https://docs.python.org/3/tutorial/classes.html#generators)
#     * [Decorators](https://realpython.com/blog/python/primer-on-python-decorators/)
#     * [Magic Methods](http://www.rafekettler.com/magicmethods.html)
#     * [Context Manager](https://www.python.org/dev/peps/pep-0343/)
#     * All the other cool stuff
#
# - [Science](http://scipy.org/)
#     1. [Plotting](http://matplotlib.org/)
#     * [Numerical Calculations](http://www.numpy.org/)
#     * Reading/Writing Data (Txt, CSV, Binary, HDF, ...)
#     * [Fitting](http://docs.scipy.org/doc/scipy-0.16.0/reference/generated/scipy.optimize.curve_fit.html)
#     * [FFT](http://docs.scipy.org/doc/scipy/reference/fftpack.html)
#     * [Symbolic Math](http://www.sympy.org/en/index.html)
#     * [Plotly](https://plot.ly/)
#
# - [Pymeasure](https://github.com/t--wagner/pymeasure)
#
# - Tools
#     1. [IPython](http://www.ipython.org) and [Jupyter](http://www.jupyter.org)
#     * [Spyder IDE](https://github.com/spyder-ide)
#     * [pip]()/[PyPI](https://pypi.python.org/pypi) and [conda]()
#     * [Git](https://git-scm.com/) and [Github](https://github.com/)
#     * [virtualenv](https://github.com/pypa/virtualenv/blob/master/docs/index.rst)
#
# - Be Pythonic
#     1. [Zen of Python](https://www.python.org/dev/peps/pep-0020/)
#     * [PEP 8](https://www.python.org/dev/peps/pep-0008/)
#     * [Docstrings](https://docs.python.org/3/tutorial/controlflow.html#documentation-strings) and [Spinx](http://sphinx-doc.org/)
#     * [Ducktyping](https://en.wikipedia.org/wiki/Duck_typing)
#     * [Design Patterns](https://en.wikipedia.org/wiki/Software_design_pattern)
#     * [Functional programming](https://docs.python.org/3.5/howto/functional.html)
#     * [Unicode](https://de.wikipedia.org/wiki/Unicode) and [UTF-8](https://de.wikipedia.org/wiki/UTF-8)
#
# - Speed
#     1. [Numpy](http://www.numpy.org)
#     * [Cython](http://www.cython.org)

# %% [markdown]
# # Python

# %% [markdown]
# <a href='http://www.python.org'>
#     <img src="images/python_logo.png", align='left'>
# </a>

# %% [markdown]
# * [Documentation](https://docs.python.org/3/)
# * [Online Course](http://www.python-kurs.eu/python3_kurs.php): Python 3 Tutorial (English and German)
# * [Online Book](https://automatetheboringstuff.com/) with some [Videos](https://www.youtube.com/playlist?list=PL0-84-yl1fUnRuXGFe_F7qSH1LEnn9LkW): Automate the Boring Stuff with Python.
# * [Online Book](http://openbookproject.net/thinkcs/python/english3e/) and [interactive Tutorial](http://interactivepython.org/runestone/static/thinkcspy/index.html): How to Think Like a Computer Scientist: Learning with Python 3
#
#
# * [PyCon](https://us.pycon.org/): Videos of [2015](https://www.youtube.com/channel/UCgxzjK6GuOHVKR_08TT4hJQ), [2014](https://www.youtube.com/user/PyCon2014), [2013](https://www.youtube.com/playlist?list=PLVHWQfFw_gm4c1Wz7Ga7CevlsRi-yX-tG), ...
# * [SyiPy](http://conference.scipy.org/): Videos of [2015](https://www.youtube.com/playlist?list=PLYx7XA2nY5Gcpabmu61kKcToLz0FapmHu),  [2014](https://www.youtube.com/playlist?list=PLYx7XA2nY5GfuhCvStxgbynFNrxr3VFog), [2013](https://www.youtube.com/playlist?list=PL4Sy54pq-Jk0-fTFMMEppN9D4c3iyttwQ), ...
# * [EuroPython](https://ep2015.europython.eu/en/): Videos of [2015](europython 2015), [2014](https://www.youtube.com/user/europython2014), ...

# %% [markdown]
# #  Scientific Python Distributions
#
# All distributions provide the same functionality.

# %% [markdown]
# <a href="https://winpython.github.io/">
#     <img src="images/winpython_logo.png", align="left">
# </a>

# %% [markdown]
# * portable
# * Do not download the Qt5 version at the moment.

# %% [markdown]
# <a href="https://www.continuum.io/">
#     <img src="images/anaconda_logo.png", align="left">
# </a>

# %% [markdown]
# * platform independent (Window, Linux, Mac)

# %% [markdown]
# <a href='https://www.enthought.com/products/canopy/'>
#     <img src='images/canopy_logo.png', align='left'>
# </a>

# %% [markdown]
# * platform independent (Window, Linux, Mac)

# %% [markdown]
# #  Scientific Packages

# %% [markdown]
# <a href='http://ipython.org/'>
#     <img src="images/ipython_logo.png", align="left"*>
# </a>

# %%
import IPython
IPython.__version__
# Out:
# '4.0.0'

# %% [markdown]
# * [Documentation](https://ipython.org/documentation.html)
# * [Quickstart](http://nbviewer.ipython.org/github/ipython/ipython/blob/3.x/examples/Notebook/Index.ipynb)
# * [Video Tutorial](https://www.youtube.com/watch?v=05fA_DXgW-Y) with [Notebooks](https://github.com/ipython/ipython-in-depth): IPython & Jupyter in depth: high productivity interactive and parallel python, PyCon 2015
# * [Book](http://www.amazon.de/IPython-Interactive-Computing-Visualization-Cookbook/dp/1783284811/ref=sr_1_1?ie=UTF8&qid=1447512454&sr=8-1&keywords=ipython): IPython Interactive Computing and Visualization Cookbook, Packt Publishing (2014)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("05fA_DXgW-Y")
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/05fA_DXgW-Y"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# <a href="http://numpy.org/">
#     <img src="images/numpy_logo.jpg", align="left">
# </a>

# %%
import numpy
numpy.__version__
# Out:
# '1.9.3'

# %% [markdown]
# <i>"NumPy is an extension to the Python programming language, adding <b>support for large, multi-dimensional arrays and matrices</b>, along with a large library of <b>high-level mathematical functions</b> to operate on these arrays.
#
# Using NumPy in Python gives <b>functionality comparable to MATLAB</b> ..."</i>, [Wikipedia](https://en.wikipedia.org/wiki/NumPy)
# * [Documentation](http://docs.scipy.org/doc/)
# * [Quickstart](https://docs.scipy.org/doc/numpy-dev/user/quickstart.html)
# * [Video Tutorial](https://www.youtube.com/watch?v=MKucn8NtVeI) with [Slides](https://github.com/enthought/Numpy-Tutorial-SciPyConf-2015): Introduction to NumPy, SciPy 2015
# * [Book](http://www.amazon.com/Numpy-Beginners-Guide-Ivan-Idris/dp/1785281968/ref=sr_1_1?ie=UTF8&qid=1447519228&sr=8-1&keywords=numpy+beginner+guide): Numpy Beginner's Guide - Third Edition, Packt Publishing (2015)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("1zmV8lZsHF4")
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/1zmV8lZsHF4"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# <a href="http://matplotlib.org/">
#     <img src="images/matplotlib_logo.png", align="left">
# </a>

# %%
import matplotlib
matplotlib.__version__
# Out:
# '1.5.0rc3'

# %% [markdown]
# <i>matplotlib is a <b>plotting library</b> for the Python programming language and its numerical mathematics extension NumPy.
#
# There is also a procedural "pylab" interface ..., designed to closely resemble that of MATLAB.</i>
#
# * [Documentation](http://matplotlib.org/contents.html): Guides, FAQ, Resources, API, ...
# * [Gallery](http://matplotlib.org/gallery.html): Unterschiedlichste Plots mit Code Beispielen
# * [Quickstart](http://matplotlib.org/users/pyplot_tutorial.html)
# * [Video Tutorial](https://www.youtube.com/watch?v=MKucn8NtVeI) with [Notebooks](https://github.com/WeatherGod/AnatomyOfMatplotlib): Anatomy of matplotlib, SciPy (2015)
# * [Buch](http://www.amazon.de/Mastering-matplotlib-Duncan-M-McGreggor/dp/1783987545): Mastering matplotlib, Packt Publishing (2015)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("MKucn8NtVeI")
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/MKucn8NtVeI"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# <a href='http://www.scipy.org'>
#     <img src="images/scipy_logo.png", align="left">
# </a>

# %%
import scipy
scipy.__version__
# Out:
# '0.16.1'

# %% [markdown]
# <i>"SciPy contains modules for <b>optimization, linear algebra, integration, interpolation, special functions, FFT, signal and image processing, ODE solvers</b> and other tasks common in science and engineering."</i>, [Wikipedia](https://en.wikipedia.org/wiki/SciPy)
#
# * [Documentation](http://docs.scipy.org/doc/scipy/reference/)
# * [Book](http://www.amazon.com/Learning-Numerical-Scientific-Computing-Second/dp/1783987707/ref=sr_1_1?ie=UTF8&qid=1447519893&sr=8-1&keywords=scipy): Learning SciPy for Numerical and Scientific Computing Second Edition, Packt Publishing (2015)

# %% [markdown]
# <a href='http://pandas.pydata.org/'>
#     <img src='images/pandas_logo.png', align="left">
#  </a>

# %% [markdown]
# <i>"Pandas is a software library written for the Python programming language for <b>data manipulation and analysis</b>. In particular, it offers <b>data structures and operations for manipulating numerical tables and time series.</b>"</i>, [Wikpedia](Pandas is a software library written for the Python programming language for data manipulation and analysis. In particular, it offers data structures and operations for manipulating numerical tables and time series.)
#
# * [Documentation](http://pandas.pydata.org/pandas-docs/stable/)
# * [Quickstart](http://pandas.pydata.org/pandas-docs/stable/10min.html)
# * [Video Tutorial](https://www.youtube.com/watch?v=0CFFTJUZ2dc&list=PLYx7XA2nY5Gcpabmu61kKcToLz0FapmHu&index=6) with [Notebooks](https://github.com/jonathanrocher/pandas_tutorial): Analyzing and Manipulating Data with Pandas, SciPy (2015
# )* [Book](http://www.amazon.de/Python-Data-Analysis-Wrangling-IPython/dp/1449319793/ref=sr_1_1?ie=UTF8&qid=1447520499&sr=8-1&keywords=python+pandas): Python for Data Analysis: Data Wrangling with Pandas, NumPy, and IPython, O'Reilly and Associates (2012)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('0CFFTJUZ2dc')
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/0CFFTJUZ2dc"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# <a href='http://www.sympy.org'>
#     <img src='images/sympy_logo.png', align='left'>
# </a>

# %% [markdown]
# <i>"SymPy is a Python library for symbolic computation...
#
# SymPy includes features ranging from basic symbolic arithmetic to calculus, algebra, discrete mathematics and quantum physics. It is capable of formatting the result of the computations as LaTeX code."</i> [Wikipedia](https://en.wikipedia.org/wiki/SymPy#Features)
#
# * [Documentation](http://docs.sympy.org/latest/index.html)
# * [Quickstart](http://docs.sympy.org/latest/tutorial/intro.html)
# * [Video](https://www.youtube.com/watch?v=Lgp442bibDM) with [Slides](https://github.com/asmeurer/scipy-2014-tutorial): SymPy, SciPy (2014)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('Lgp442bibDM')
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/Lgp442bibDM"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# <a href='http://www.h5py.org'>
#     <img src='images/hdf_logo.jpg', align='left'>
# </a>

# %%
import h5py
h5py.__version__
# Out:
# '2.5.0'

# %% [markdown]
# <i>"HDF5 is a <b>data model, library, and file format</b> for storing and managing data. It supports an <b>unlimited variety of datatypes</b>, and is designed for <b>flexible and efficient I/O and for high volume and complex data</b>. HDF5 is <b>portable and is extensible</b>, allowing applications to evolve in their use of HDF5. The HDF5 Technology suite includes tools and applications for managing, manipulating, viewing, and analyzing data in the HDF5 format."</i>, [HDF Group](https://www.hdfgroup.org/HDF5/)
#
# * [Documentation](http://docs.h5py.org/en/latest/)
# * [Quickstart](http://docs.h5py.org/en/latest/quick.html)
# * [Video Introduction](https://www.youtube.com/watch?v=nddj5OA8LJo&list=PLYx7XA2nY5Gcpabmu61kKcToLz0FapmHu&index=9): HDF5 is Eating the World, SyiPy (2015)
# * [Book](http://www.amazon.de/Python-HDF5-Andrew-Collette-ebook/dp/B00G2QUU6U/ref=sr_1_1?ie=UTF8&qid=1447589391&sr=8-1&keywords=hdf+python): Python and HDF5, O'Reilly Media (2013)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('nddj5OA8LJo')
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/nddj5OA8LJo"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# <a href='http://cython.org/'>
#     <img src='images/cython_logo.jpg', align='left'>
# </a>

# %%
import Cython
Cython.__version__
# Out:
# '0.23.4'

# %% [markdown]
# <i>"Cython is a compiled language that generates <b>CPython extension modules</b>. These extension modules can then be loaded and used by regular Python code using the import statement.
#
# It works by producing a standard Python module. However, the behavior differs from standard Python in that the module code, originally written in Python, is translated into C. While <b>the resulting code is fast</b>, ..."
# </i>, [Wikipedia](https://en.wikipedia.org/wiki/Cython)
#
# * [Documentation](http://docs.cython.org/)
# * [Video Tutorial](https://www.youtube.com/watch?v=gMvkiQ-gOW8) with [Slides](https://github.com/kwmsmith/scipy-2015-cython-tutorial): Cython: Blend the Best of Python and C++, SciPy 2015
# * [Book](http://www.amazon.de/Cython-Kurt-W-Smith/dp/1491901551/ref=sr_1_1?ie=UTF8&qid=14475)  Cython, A Guide for Python Programmers, O'Reilly Media (2015)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('gMvkiQ-gOW8')
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/gMvkiQ-gOW8"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Examples

# %% [markdown]
# ### Typical imports

# %%
# Import necassary packages
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Set up matpltolib for nice plotting in the notebook
# %matplotlib notebook
plt.style.use('seaborn-notebook')

# %% [markdown]
# ###  Simple Plot

# %%
x = np.linspace(0, 4 * np.pi, 200)
rad = x / np.pi

plt.figure(figsize=(12, 3))
line, = plt.plot(rad, 2 * np.sin(x))
plt.ylim(-5, 5)
plt.grid()

plt.tight_layout()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### Interactive

# %%
from ipywidgets import interact

@interact(a=(1, 4), f=(0.1, 2, 0.1), phi=(0, 2, 0.1))
def update(a=2, f = 1, phi=0):
    line.set_ydata(a * np.sin((x + phi * np.pi) / f))

# %% [markdown]
# ### Subplots

# %%
x = np.linspace(0, 4 * np.pi, 200)
rad = x / np.pi

#Create some noise
noise = 0.75 * np.random.randn(x.size)

# Define differnt harmonic functions
y0 = 1.0 * np.sin(x + 0) + noise
y1 = 1.5 * np.sin(x + np.pi / 2) + noise
y2 = 2.5 * np.sin(x + np.pi) + noise


# Plot everything
fig, axs = plt.subplots(3 , 1, figsize=(12, 6))

axs[0].plot(rad, y0, 'b.')
axs[0].set_xticks([])

axs[1].plot(rad, y1, 'g.')
axs[1].set_xticks([])

axs[2].plot(rad, y2, 'k.')
axs[2].set_xlabel('x / 2$\pi$')

for ax in axs:
    ax.set_ylim(-5.5, 5.5)

plt.tight_layout(h_pad=0)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### Fitting

# %%
# Define the fit function
def sin(x, a, phi):
    return a * np.sin(x + phi)

# Find the fit parameters
(a0, phi0), *err = curve_fit(sin, x, y0)
(a1, phi1), *err = curve_fit(sin, x, y1)
(a2, phi2), *err = curve_fit(sin, x, y2)

# Plot fits into subplots
axs[0].plot(rad, sin(x, a0, phi0), 'r--', lw=3, label='${:.2f} \cdot Sin(x + {:.2f}\pi$)'.format(a0, phi0 / np.pi))
axs[1].plot(rad, sin(x, a1, phi1), 'r--', lw=3, label='${:.2f} \cdot Sin(x + {:.2f}\pi$)'.format(a1, phi1 / np.pi))
axs[2].plot(rad, sin(x, a2, phi2), 'r--', lw=3, label='${:.2f} \cdot Sin(x + {:.2f}\pi$)'.format(a2, phi2 / np.pi))

for ax in axs:
    ax.legend(loc=4)
